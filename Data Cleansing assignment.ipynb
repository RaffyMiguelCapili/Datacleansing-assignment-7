# %%
import pandas as pd

# %%
import scrubadub

# %%
import numpy as np

# %%
import os

# %%
df = pd.read_csv('assignment_seven.csv')

# %%
#Shows the first 10 data in the csv file

df.head(n=10)
# Out:
#    transaction_id transaction_date               full_name  \
# 0               1        7/19/2021           Izzy Janssens
# 1               2        9/25/2021           Timmy Sanches
# 2               3        10/7/2021       Skyler Rawlcliffe
# 3               4        5/26/2022      Torrance Petteford
# 4               5       12/17/2021          Bendite Fardon
# 5               6        3/20/2022          Foster Yarnell
# 6               7         5/3/2022        Kakalina Saveall
# 7               8        6/27/2021            Artemis Witz
# 8               9         9/9/2021      Marie-jeanne Foukx
# 9              10         3/6/2022  Jerrilee Alexandersson
#
#                               record_id  \
# 0  1df9f42a-8c0f-4e3d-aeca-5bd310dd277a
# 1  afaf2462-41b1-43dc-8702-264cf2a6ade0
# 2  34528325-deb3-4deb-9107-12a89f5d1cfc
# 3  6e379186-e61e-4926-ad03-0ac7759d7fab
# 4  b0eb4c68-5737-4076-856d-7eacf2e6014d
# 5  f38ae908-9a9e-4b1c-bfc0-9fc6a0151877
# ...

# %%
#Checking the amount of empty rows and collums in the data

df.isnull().sum()
# Out:
# transaction_id       0
# transaction_date     0
# full_name            0
# record_id           32
# products            33
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    1000 non-null   int64
#  1   transaction_date  1000 non-null   object
#  2   full_name         1000 non-null   object
#  3   record_id         968 non-null    object
#  4   products          967 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 39.2+ KB

# %%
#dropping the fields that have missing values

pd.DataFrame.dropna(df)
# Out:
#      transaction_id transaction_date           full_name  \
# 0                 1        7/19/2021       Izzy Janssens
# 1                 2        9/25/2021       Timmy Sanches
# 2                 3        10/7/2021   Skyler Rawlcliffe
# 3                 4        5/26/2022  Torrance Petteford
# 4                 5       12/17/2021      Bendite Fardon
# ..              ...              ...                 ...
# 995             996        5/26/2022    Jerrine Lomansey
# 996             997        9/11/2021         Paddy Askam
# 997             998       11/25/2021  Krystyna Champneys
# 998             999        3/11/2022   Gwendolin Layzell
# 999            1000         3/3/2022    Petronella Grout
#
#                                 record_id                        products
# 0    1df9f42a-8c0f-4e3d-aeca-5bd310dd277a             TERBUTALINE SULFATE
# 1    afaf2462-41b1-43dc-8702-264cf2a6ade0                        Fentanyl
# ...

# %%
#Cleans the name in the data for anonymization

scrub = lambda x: scrubadub.clean
df['full_name'] = df['full_name'].apply(scrub)

# %%
(df.head(n=5))
# Out:
#    transaction_id transaction_date                               full_name  \
# 0               1        7/19/2021  <function clean at 0x00000229F228F130>
# 1               2        9/25/2021  <function clean at 0x00000229F228F130>
# 2               3        10/7/2021  <function clean at 0x00000229F228F130>
# 3               4        5/26/2022  <function clean at 0x00000229F228F130>
# 4               5       12/17/2021  <function clean at 0x00000229F228F130>
#
#                               record_id             products
# 0  1df9f42a-8c0f-4e3d-aeca-5bd310dd277a  TERBUTALINE SULFATE
# 1  afaf2462-41b1-43dc-8702-264cf2a6ade0             Fentanyl
# 2  34528325-deb3-4deb-9107-12a89f5d1cfc            Lorazepam
# 3  6e379186-e61e-4926-ad03-0ac7759d7fab          risperidone
# 4  b0eb4c68-5737-4076-856d-7eacf2e6014d               Oxygen

# %%
df.to_csv("assignment_sevenclean.csv")
